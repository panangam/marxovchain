# %%
from newsapi import NewsApiClient
import requests
from PIL import Image, ImageOps
from marxify import Marxify

# %%
newsapi = NewsApiClient(api_key='bbba33d91ef64b5cafeea9be97da9538')
res = newsapi.get_top_headlines(country='gb')

# %%
articleJson = sorted([r for r in res['articles'] if r['content'] is not None], key=lambda r: r['content'])[1]

# %%
imageUrl = articleJson['urlToImage']
image = Image.open(requests.get(imageUrl, stream=True).raw).convert(mode='RGBA')
communistSymbol = Image.open('assets/hammer_sickle_and_star.png').resize((180,200))

# %%
width, height = image.size
image = image.resize((800,450))
image.alpha_composite(communistSymbol, (10,10))
#image = ImageOps.posterize(image.convert(mode='RGB'), bits=4)
image
# Out:
# <PIL.Image.Image image mode=RGBA size=800x450 at 0x2280F16CC88>

# %%
model = Marxify(articleJson['content'][:-15])
status = model.makeCommunistSentence()
status += ' #%s #%s #%s #marxovchain' % (model._keywords[0], model._keywords[1], model._keywords[2])
status
# Out:
# 'As President Donald Trump met with senior members of the bourgeois mode of production in unaltered form, was, on the eve of a revolution, but administrative reforms, based on the civilised ones, nations of bourgeois, the East on the conditions of existence. #trump #sparked #stately #marxovchain'

# %%
image.save('pic.png')

# %%
model._keywords

# %%
import markovify
articleJson['content'][:-15]
# Out:
# "A candlelight vigil, held in Hong Kong's Victoria Park on Tuesday, remembered the victims of the 1989 massacre in Beijing's Tiananmen Square.\r\nTens of thousands of people gathered in Hong Kong's Victoria Park on Tuesday to mark the 30th anniversary of the Ti"

# %%
import tweepy

consumer_key = 'WrPTmBaJESVs7eLfwkiVaqQ7U'
consumer_secret = 'Xa1Vq8Ze5i7SAnj2EdAINnAZOJlVYmWekiAGPXEoXinhp5opE2'
access_token = '3264530906-hJ0arh1odGptrBosf5szy8F1O6BpxygzA91WNf0'
access_token_secret = 'VsmPmWdYZ3R20zkGKH0cgYcEufSlF7v07j1Wpj847y6ms'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

twitterApi = tweepy.API(auth)

# %%
twitterApi.update_with_media(status=status, filename='pic.png')
# Out:
# Status(_api=<tweepy.api.API object at 0x000002280F0C53C8>, _json={'created_at': 'Tue Jun 04 20:07:11 +0000 2019', 'id': 1136001473546924033, 'id_str': '1136001473546924033', 'text': 'Gonorrhoea diagnoses in England have risen to their historical position, it became the vocation of the soil general… https://t.co/pP75pSzhtK', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/pP75pSzhtK', 'expanded_url': 'https://twitter.com/i/web/status/1136001473546924033', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://manna.orasphong.com" rel="nofollow">manna-test</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3264530906, 'id_str': '3264530906', 'name': 'Oras Phong', 'screen_name': 'orasphong', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 2, 'listed_count': 0, 'created_at': 'Wed Jul 01 17:35:08 +0000 2015', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 6, 4, 20, 7, 11), id=1136001473546924033, id_str='1136001473546924033', text='Gonorrhoea diagnoses in England have risen to their historical position, it became the vocation of the soil general… https://t.co/pP75pSzhtK', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/pP75pSzhtK', 'expanded_url': 'https://twitter.com/i/web/status/1136001473546924033', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='manna-test', source_url='http://manna.orasphong.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000002280F0C53C8>, _json={'id': 3264530906, 'id_str': '3264530906', 'name': 'Oras Phong', 'screen_name': 'orasphong', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 2, 'listed_count': 0, 'created_at': 'Wed Jul 01 17:35:08 +0000 2015', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_ ...
